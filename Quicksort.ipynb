# %%
lista = [0, 3, 5]
print(lista[2])
# Out:
# 5

# %%
def quicksort(arr):
  if len(arr) <= 1:
    return arr
  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]
  return quicksort(left) + middle + quicksort(right)

# %%
arr = [5, 3, 8, 4, 6, 3, 2, 123, 532, 15, 1, 123, 23, 4, 6, 7, 6312]

print('lista original -> ', arr)
print('lista com quicksort -> ', quicksort(arr))
# Out:
# lista original ->  [5, 3, 8, 4, 6, 3, 2, 123, 532, 15, 1, 123, 23, 4, 6, 7, 6312]
# lista com quicksort ->  [1, 2, 3, 3, 4, 4, 5, 6, 6, 7, 8, 15, 23, 123, 123, 532, 6312]
